# %% [markdown]
# Tạo cửa sổ GUI và đặt tiêu đề (Tkinter)

# %%
import tkinter as tk

# Tạo cửa sổ chính
window = tk.Tk()

# Đặt tiêu đề cho cửa sổ
window.title("Hello Tkinter")

# Giữ cửa sổ hiển thị
window.mainloop()
