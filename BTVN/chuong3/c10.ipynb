# %%
import pandas as pd
drink = pd.read_csv("drinks.csv", index_col=0)
print(type(drink))
print(drink.shape)
print(drink.columns)
print(drink.head())
print(drink.tail())
# 2. Trung bình bia theo châu lục
print(drink.groupby("continent")["beer_servings"].mean())

# 3. Thống kê rượu vang theo châu lục
print(drink.groupby("continent")["wine_servings"].describe())

# 4. Mean bia + rượu theo châu lục
print(drink.groupby("continent")[["beer_servings", "wine_servings"]].mean())

# 5. Median bia + rượu theo châu lục
print(drink.groupby("continent")[["beer_servings", "wine_servings"]].median())

# 6. Spirit: mean – max – min theo châu lục
print(drink.groupby("continent")["spirit_servings"].agg(["mean", "max", "min"]))

# 7. Sắp xếp theo beer_servings
sorted_beer = drink.sort_values(by="beer_servings")
print(sorted_beer)

# 5 ít nhất
print(sorted_beer.head(5))

# 5 nhiều nhất
print(sorted_beer.tail(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (10, 6)
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               45             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa
#       country  beer_servings  spirit_servings  wine_servings  \
# 5   Argentina            193               25            221
# 6     Armenia             21              179              3
# 7   Australia            261               72            212
# 8     Austria            279               75            191
# 9  Azerbaijan             21               46              5
#
#    total_litres_of_pure_alcohol      continent
# 5                           8.3  South America
# 6                           3.8           Asia
# 7                          10.4        Oceania
# 8                           9.7         Europe
# 9                           2.0           Asia
# continent
# Africa           121.000000
# Asia              14.000000
# Europe           204.333333
# Oceania          261.000000
# South America    193.000000
# Name: beer_servings, dtype: float64
#                count        mean         std    min     25%    50%     75%  \
# continent
# Africa           2.0   29.500000   21.920310   14.0   21.75   29.5   37.25
# Asia             3.0    2.666667    2.516611    0.0    1.50    3.0    4.00
# Europe           3.0  185.666667  129.082661   54.0  122.50  191.0  251.50
# Oceania          1.0  212.000000         NaN  212.0  212.00  212.0  212.00
# South America    1.0  221.000000         NaN  221.0  221.00  221.0  221.00
#
#                  max
# continent
# Africa          45.0
# Asia             5.0
# Europe         312.0
# Oceania        212.0
# South America  221.0
#                beer_servings  wine_servings
# continent
# Africa            121.000000      29.500000
# Asia               14.000000       2.666667
# Europe            204.333333     185.666667
# Oceania           261.000000     212.000000
# South America     193.000000     221.000000
#                beer_servings  wine_servings
# continent
# Africa                 121.0           29.5
# Asia                    21.0            3.0
# Europe                 245.0          191.0
# Oceania                261.0          212.0
# South America          193.0          221.0
#                 mean  max  min
# continent
# Africa          22.5   45    0
# Asia            75.0  179    0
# Europe         115.0  138   75
# Oceania         72.0   72   72
# South America   25.0   25   25
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 6      Armenia             21              179              3
# 9   Azerbaijan             21               46              5
# 2      Algeria             25                0             14
# 1      Albania             89              132             54
# 5    Argentina            193               25            221
# 4       Angola            217               45             45
# 3      Andorra            245              138            312
# 7    Australia            261               72            212
# 8      Austria            279               75            191
#
#    total_litres_of_pure_alcohol      continent
# 0                           0.0           Asia
# 6                           3.8           Asia
# 9                           2.0           Asia
# 2                           0.7         Africa
# 1                           4.9         Europe
# 5                           8.3  South America
# 4                           5.9         Africa
# 3                          12.4         Europe
# 7                          10.4        Oceania
# 8                           9.7         Europe
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 6      Armenia             21              179              3
# 9   Azerbaijan             21               46              5
# 2      Algeria             25                0             14
# 1      Albania             89              132             54
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 6                           3.8      Asia
# 9                           2.0      Asia
# 2                           0.7    Africa
# 1                           4.9    Europe
#      country  beer_servings  spirit_servings  wine_servings  \
# 5  Argentina            193               25            221
# 4     Angola            217               45             45
# 3    Andorra            245              138            312
# 7  Australia            261               72            212
# 8    Austria            279               75            191
#
#    total_litres_of_pure_alcohol      continent
# 5                           8.3  South America
# 4                           5.9         Africa
# 3                          12.4         Europe
# 7                          10.4        Oceania
# 8                           9.7         Europe
