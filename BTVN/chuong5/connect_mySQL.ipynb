# %%
import mysql.connector
PORT = 3307
USER = "root"
PASSWORD = "uneti"
DATABASE = "data_science_db"
HOST = "127.0.0.1"
conn = mysql.connector.connect(
        host=HOST,
        user=USER,
        password=PASSWORD,
        database=DATABASE,
        port=PORT
)
