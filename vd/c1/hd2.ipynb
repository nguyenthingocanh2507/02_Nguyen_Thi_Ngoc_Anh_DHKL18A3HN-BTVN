# %%
#Ngày 9/10
#XML :là ngôn ngữ đánh dấu mở rộng
# cú pháp tài liệu XML:  <name>nội dung</name>
                         # thẻ mở _ thẻ đóng  
    # ĐỂ BỔ SUNG các thuộc tính vào thẻ xml , sdug cú phapsss 
# thuộc tính và thẻ mở ,đóng k dùng dấu cách - vd : hoten, namsinh
