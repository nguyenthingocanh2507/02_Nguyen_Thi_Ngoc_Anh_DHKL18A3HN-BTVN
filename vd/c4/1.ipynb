# %%
import pandas as pd
import numpy as np
# series từ dict
 
s= pd.Series({'a':1.0,'b':2.0,'c':3.0})
print("series:\n",s)


# dataframe từ mảng numpy 2D
arr=np.arange(1,10).reshape(3,3)
df= pd.DataFrame(arr,columns=['col1','col2','col3'])
print("\nDataframe",df)
# Out:
# series:
#  a    1.0
# b    2.0
# c    3.0
# dtype: float64
#
# Dataframe    col1  col2  col3
# 0     1     2     3
# 1     4     5     6
# 2     7     8     9

# %%
import pandas as pd
data=pd.Series([1.0,0.25,6.0,0.75])
print(data)
data[0] # thứ tự trog số liệu data trên 
type(data)  #kiểu dữ liệu của data 
data.index # data chỉ mục nào 
data.dtype # in ra kiểu dl là float hay str hay int

# %%
population_dict={      # khởi tạo populatin chứ dữ liệu ds các tỉnh 
    'hà nội': 8330830,    
    'quảng ninh':1358085,
    'nam định': 1836270,
    'đà nẵng':1195490,
    'tp hồ chí minh': 9411805
}
population= pd.Series(population_dict,name= 'dân số tỉnh /thành phố' )
print(population)
print("dân số hn",population['hà nội']) # in ra 1 tỉnh hà nội
# ví dụ minh hoá thuộc tính của series 
print(f'mảng số liệu dân số:',population.values) # series = giá trị bên trong mỗi nhãn( index)
type(population.values)
print(population.index) # in ra nhãn của trog population dict


population


area_dict={'Hà Nội':3358.9, 
            'Quảng Ninh':6177.7, 
            'Nam Định':1668.0, 
            'Đà Nẵng':1284.9, 
            'TP.Hồ Chí Minh':2061.0} 
area = pd.Series(area_dict) 
area
VietNam = pd.DataFrame({'Dân số':population, 'Diện tích':area}) 
VietNam
VietNam.columns # in ra các mục nhãn của các cột trong bảng dữ liệu 
print("kích thước bảng :số hàng ,cột :",df.shape)
# Out:
# hà nội            8330830
# quảng ninh        1358085
# nam định          1836270
# đà nẵng           1195490
# tp hồ chí minh    9411805
# Name: dân số tỉnh /thành phố, dtype: int64
# dân số hn 8330830
# mảng số liệu dân số: [8330830 1358085 1836270 1195490 9411805]
# Index(['hà nội', 'quảng ninh', 'nam định', 'đà nẵng', 'tp hồ chí minh'], dtype='object')
#                    Dân số  Diện tích
# Hà Nội                NaN     3358.9
# Nam Định              NaN     1668.0
# Quảng Ninh            NaN     6177.7
# TP.Hồ Chí Minh        NaN     2061.0
# hà nội          8330830.0        NaN
# nam định        1836270.0        NaN
# quảng ninh      1358085.0        NaN
# tp hồ chí minh  9411805.0        NaN
# Đà Nẵng               NaN     1284.9
# đà nẵng         1195490.0        NaN

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Tạo dữ liệu dân số
population = pd.Series({
    'Hà Nội': 8250000,
    'TP.Hồ Chí Minh': 9100000,
    'Đà Nẵng': 1200000,
    'Nam Định': 1800000,
    'Quảng Ninh': 1400000
})

# Vẽ biểu đồ
population.plot(kind='bar', title='Dân số các tỉnh/TP (nguồn GSO 2022)')
plt.ylabel("Số người")
plt.show()

# %%
import sys
# !{sys.executable} -m pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 604.9 kB/s eta 0:00:13
#    -- ------------------------------------- 0.5/8.1 MB 604.9 kB/s eta 0:00:13
#    -- ------------------------------------- 0.5/8.1 MB 604.9 kB/s eta 0:00:13
#    --- ------------------------------------ 0.8/8.1 MB 546.3 kB/s eta 0:00:14
#    --- ------------------------------------ 0.8/8.1 MB 546.3 kB/s eta 0:00:14
#    ----- ---------------------------------- 1.0/8.1 MB 583.7 kB/s eta 0:00:13
#    ----- ---------------------------------- 1.0/8.1 MB 583.7 kB/s eta 0:00:13
#    ------ --------------------------------- 1.3/8.1 MB 590.3 kB/s eta 0:00:12
# ...

# %%
# !python -m pip install pandas
